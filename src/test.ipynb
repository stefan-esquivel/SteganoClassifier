# %%
# !pwd
# Out:
# /home/jovyan

# %%
import os
import tensorflow as tf

# %%
from tensorflow import keras

# %%
# !pwd
# Out:
# /home/jovyan

# %%
os.chdir("/home/jovyan/work/data/Test/")

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('0001.jpg')

plt.imshow(img)
