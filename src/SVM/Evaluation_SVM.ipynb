# %% [markdown]
# # Evaluation of SVM

# %%
## For google colab
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
import os
os.chdir("/content/drive/My Drive/SENG474-FinalProject")

# %%
import pandas as pd

df = pd.read_csv('log_abc.csv')

# %%
df.head()
# Out:
#    samples  accuracy       loss  val_accuracy   val_loss
# 0     1000  0.501033   7.460548        0.4898  17.960516
# 1     2000  0.501944   1.865116        0.4828  17.787673
# 2     3000  0.501300  10.718782        0.4889  18.041121
# 3     4000  0.500111   9.627684        0.4986  16.863615
# 4     5000  0.501378   8.655617        0.4853  18.015763

# %%
from matplotlib import pyplot as plt
plt.plot(df['samples'], df['accuracy'])
plt.plot(df['samples'], df['val_accuracy'])
plt.title('SVM Accuracy')
plt.ylabel('accuracy')
plt.xlabel('samples')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(df['samples'], df['loss'])
plt.plot(df['samples'], df['val_loss'])
plt.title('SVM Loss')
plt.ylabel('loss')
plt.xlabel('samples')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
