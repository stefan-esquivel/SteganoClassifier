# %% [markdown]
# # Evaluation of GBRAS-net Convolutional Nural Network

# %%
## For google colab
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
import os
os.chdir("/content/drive/My Drive/SENG474-FinalProject")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv('log_deep.csv')

# %%
df.head()
# Out:
#    epoch  accuracy      loss  val_accuracy  val_loss
# 0      0  0.503444  0.695920         0.488  0.696840
# 1      1  0.498667  0.693759         0.506  0.692562
# 2      2  0.492667  0.693694         0.493  0.693464
# 3      3  0.494000  0.693413         0.502  0.693121
# 4      4  0.494444  0.693555         0.492  0.693546

# %%
import keras
from matplotlib import pyplot as plt
plt.plot(df['accuracy'])
plt.plot(df['val_accuracy'])
plt.title('GBRAS-net CNN Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(df['loss'])
plt.plot(df['val_loss'])
plt.title('GBRAS-net CNN Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
